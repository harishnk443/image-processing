# %%
import cv2
import matplotlib.pyplot as plt
imge1=plt.imread('merry.jpg')
imge2=plt.imread('merry2.jpg')
plt.imshow(imge1)
plt.show()
plt.imshow(imge2)
plt.show()
addimg=imge1+imge2
plt.imshow(addimg)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
imge1=plt.imread('merry.jpg')
imge2=plt.imread('merry2.jpg')
plt.imshow(imge1)
plt.show()
plt.imshow(imge2)
plt.show()
addimg=imge1-imge2
plt.imshow(addimg)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
imge1=plt.imread('merry.jpg')
imge2=plt.imread('merry2.jpg')
plt.imshow(imge1)
plt.show()
plt.imshow(imge2)
plt.show()
addimg=imge1*imge2
plt.imshow(addimg)
plt.show()

# %%
import cv2
import matplotlib.pyplot as plt
imge1=plt.imread('merry.jpg')
imge2=plt.imread('merry2.jpg')
plt.imshow(imge1)
plt.show()
plt.imshow(imge2)
plt.show()
addimg=imge1/imge2
plt.imshow(addimg)
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp/ipykernel_12332/717074952.py:9: RuntimeWarning: divide by zero encountered in true_divide
#   addimg=imge1/imge2
# C:\Users\User\AppData\Local\Temp/ipykernel_12332/717074952.py:9: RuntimeWarning: invalid value encountered in true_divide
#   addimg=imge1/imge2
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
